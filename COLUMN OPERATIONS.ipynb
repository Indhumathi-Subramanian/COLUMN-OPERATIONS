# %% [markdown]
# ## COLUMN OPERATIONS

# %% [markdown]
# ### SALES DATA - YEARLY SALES DATA CUSTOMER WISE

# %% [markdown]
# #### Sales data arranged in a manner which gives daily, monthly, and yearly insight of different products ordered by the customers. It also contains the demographics of the customers including (Country, State, Age etc.)

# %%
import pandas as pd

# %% [markdown]
# ####  The pandas library is imported as pd for column operations.

# %%
sample = pd.read_csv("C://Users//indhu//OneDrive//Documents//datasets_python//sales_data.csv")

# %% [markdown]
# #### Using read_csv function, sales dataset is read from the location.

# %%
sample
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# #### This dataset is downloaded from the kaggle.com

# %%
sample['Unit_Profit'] = sample['Unit_Price'] + sample['Unit_Cost']
sample
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# #### The new variable 'Unit_Profit' is derived .

# %%
sample.rename(columns={'Revenue':'Sales'})
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# #### Here, the variable name 'Revenue' is renamed as 'Sales'.

# %%
sample.rename(columns={'Customer_Age':'Age', 'Customer_Gender':'Gender'})
# Out:
#               Date  Day     Month  Year  Age       Age_Group Gender  \
# 0       2013-11-26   26  November  2013   19     Youth (<25)      M
# 1       2015-11-26   26  November  2015   19     Youth (<25)      M
# 2       2014-03-23   23     March  2014   49  Adults (35-64)      M
# 3       2016-03-23   23     March  2016   49  Adults (35-64)      M
# 4       2014-05-15   15       May  2014   47  Adults (35-64)      F
# ...            ...  ...       ...   ...  ...             ...    ...
# 113031  2016-04-12   12     April  2016   41  Adults (35-64)      M
# 113032  2014-04-02    2     April  2014   18     Youth (<25)      M
# 113033  2016-04-02    2     April  2016   18     Youth (<25)      M
# 113034  2014-03-04    4     March  2014   37  Adults (35-64)      F
# 113035  2016-03-04    4     March  2016   37  Adults (35-64)      F
#
#                Country             State Product_Category Sub_Category  \
# 0               Canada  British Columbia      Accessories   Bike Racks
# ...

# %% [markdown]
# #### Two variables names namely, 'Customer_Age' and  'Customer_Gender' has been renamed as Age and Gender.

# %%
sample.drop(['Unit_Cost' , 'Unit_Profit'],axis=1)
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# #### The variable 'Unit_Cost' and 'Unit_Profit' has been dropped from the dataset.

# %%
sample.drop('Unit_Price',axis=1, inplace=True)

# %%
sample
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# #### The Unit_Price variable has been removed.

# %%
sample.columns= [col.upper()for col in sample.columns]
sample.columns
# Out:
# Index(['DATE', 'DAY', 'MONTH', 'YEAR', 'CUSTOMER_AGE', 'AGE_GROUP',
#        'CUSTOMER_GENDER', 'COUNTRY', 'STATE', 'PRODUCT_CATEGORY',
#        'SUB_CATEGORY', 'PRODUCT', 'ORDER_QUANTITY', 'UNIT_COST', 'UNIT_PRICE',
#        'PROFIT', 'COST', 'REVENUE', 'UNIT_PROFIT'],
#       dtype='object')

# %% [markdown]
# #### The variable names has been converted to upper case.

# %%
sample.columns=[col.lower() for col in sample.columns]
sample.columns
# Out:
# Index(['date', 'day', 'month', 'year', 'customer_age', 'age_group',
#        'customer_gender', 'country', 'state', 'product_category',
#        'sub_category', 'product', 'order_quantity', 'unit_cost', 'unit_price',
#        'profit', 'cost', 'revenue', 'unit_profit'],
#       dtype='object')

# %% [markdown]
# #### The variable names has been changed to lower case.

# %%
sample.sort_values(by= ['Customer_Age', 'Product'], ascending= [True,True])
# Out:
#              Date  Day     Month  Year  Customer_Age      Age_Group  \
# 16948  2014-04-20   20     April  2014            17    Youth (<25)
# 16949  2016-04-20   20     April  2016            17    Youth (<25)
# 17072  2013-12-04    4  December  2013            17    Youth (<25)
# 17073  2015-12-04    4  December  2015            17    Youth (<25)
# 17448  2014-07-14   14      July  2014            17    Youth (<25)
# ...           ...  ...       ...   ...           ...            ...
# 135    2016-02-19   19  February  2016            87  Seniors (64+)
# 78876  2014-02-19   19  February  2014            87  Seniors (64+)
# 78877  2014-02-19   19  February  2014            87  Seniors (64+)
# 78878  2016-02-19   19  February  2016            87  Seniors (64+)
# 78879  2016-02-19   19  February  2016            87  Seniors (64+)
#
#       Customer_Gender  Country              State Product_Category  \
# 16948               F   Canada   British Columbia         Clothing
# ...

# %% [markdown]
# #### The observations has been sorted based on the customer age and the product.

# %%
sample.groupby('Country').count()
# Out:
#                  Date    Day  Month   Year  Customer_Age  Age_Group  \
# Country
# Australia       23936  23936  23936  23936         23936      23936
# Canada          14178  14178  14178  14178         14178      14178
# France          10998  10998  10998  10998         10998      10998
# Germany         11098  11098  11098  11098         11098      11098
# United Kingdom  13620  13620  13620  13620         13620      13620
# United States   39206  39206  39206  39206         39206      39206
#
#                 Customer_Gender  State  Product_Category  Sub_Category  \
# Country
# Australia                 23936  23936             23936         23936
# Canada                    14178  14178             14178         14178
# France                    10998  10998             10998         10998
# Germany                   11098  11098             11098         11098
# United Kingdom            13620  13620             13620         13620
# ...

# %% [markdown]
# #### The observations are grouped based on country.

# %%
print(sample['Product_Category'].isnull().sum())
# Out:
# 0

# %% [markdown]
# #### There is no missing values in the Product_Category variable column.

# %%
print(len(sample.columns.values))
# Out:
# 17

# %% [markdown]
# #### 17 variables present in the dataset.

# %%
print(sample.columns)
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Profit',
#        'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# #### The variable names of the dataset.
